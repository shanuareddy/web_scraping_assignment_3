# %% [markdown]
# 5. Write a program to scrap geospatial coordinates (latitude, longitude) of a city searched on google

# %%
#importing all the required libraries
import pandas as pd
import selenium
import time
from selenium import webdriver
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
import warnings
warnings.filterwarnings("ignore")
from selenium.webdriver.common.keys import Keys

# %%
driver=webdriver.Chrome("chromedriver.exe")

# %%
driver.get("https://maps.google.com/")

# %%
city=input("enter city name :")
driver.find_element_by_xpath("//input[@class='tactile-searchbox-input']").send_keys(city)
driver.find_element_by_xpath("/html/body/div[3]/div[9]/div[3]/div[1]/div[1]/div[1]/div[2]/div[1]").click()
# Out:
# enter city name :hyderabad

# %%
latitude=driver.current_url.split('/@')[1].split(',')[0]
longtitude=driver.current_url.split('/@')[1].split(',')[1].split(',')[0]
print('Latitude:',latitude,'Longitude:',longtitude)
# Out:
# Latitude: 17.4121531 Longitude: 78.127847

# %% [markdown]
# 6. Write a program to scrap details of all the funding deals for second quarter (i.e Jan 21 – March 21)
# from trak.in.

# %%
#loading the driver and the url
driver=webdriver.Chrome('chromedriver.exe')
driver.get('https://trak.in/')
time.sleep(2)

# %%
driver.get(driver.find_element_by_xpath('//li[@id="menu-item-51510"]/a').get_attribute('href'))

# %%
#creating the empty list 
date=[]
name=[]
industry=[]
sub=[]
city=[]
investor=[]
inv_type=[]
amount=[]

# %%
#scrapping for date
for i in driver.find_elements_by_xpath('//td[@class="column-2"]'):
    date.append(i.text)

#scrapping for name
for i in driver.find_elements_by_xpath('//td[@class="column-3"]'):
    name.append(i.text)

#scrapping for industry    
for i in driver.find_elements_by_xpath('//td[@class="column-4"]'):
    industry.append(i.text)

#scrapping for sub industry
for i in driver.find_elements_by_xpath('//td[@class="column-5"]'):
    sub.append(i.text)

#scrapping for city    
for i in driver.find_elements_by_xpath('//td[@class="column-6"]'):
    city.append(i.text)

#scrapping for investor
for i in driver.find_elements_by_xpath('//td[@class="column-7"]'):
    investor.append(i.text)

#scrapping for investor type    
for i in driver.find_elements_by_xpath('//td[@class="column-8"]'):
    inv_type.append(i.text)

#scrapping for amount
for i in driver.find_elements_by_xpath('//td[@class="column-9"]'):
    amount.append(i.text)

# %%
#checking for length of each columns
len(date),len(name),len(industry),len(sub),len(city),len(investor),len(inv_type),len(amount)
# Out:
# (393, 393, 393, 393, 393, 393, 393, 393)

# %%
#creating the dataframe for Jan-march
Funding={'Date':date,'Name':name,'Industry/Vertica':industry,'Sub-vertical':sub,'City':city,'Investor':investor,
        'Investment Type':inv_type,'Amount':amount}
Funding=pd.DataFrame(data=Funding)
Funding[6:30]
# Out:
#           Date                    Name        Industry/Vertica  \
# 6   04/03/2021               DealShare              E-commerce
# 7   31/03/2021                Uniphore              Technology
# 8   30/03/2021                   Dunzo              E-commerce
# 9   30/03/2021                  BYJU’S                Edu-tech
# 10  23/03/2021             SkilloVilla                Edu-tech
# 11  25/03/2021                CityMall              E-commerce
# 12  26/03/2021                   DotPe                 FinTech
# 13  11/02/2021                Doubtnut                Edu Tech
# 14  22/02/2021                  Zomato             Hospitality
# 15  19/02/2021               Fingerlix             Hospitality
# 16  17/02/2021                   Zolve                 FinTech
# 17  15/02/2021               KreditBee                 Finance
# 18  12/02/2021               Pepperfry              E-commerce
# 19  12/02/2021                 Grofers              E-Commerce
# 20  09/02/2021                 Nothing              Technology
# 21  09/02/2021             SplashLearn                  EdTech
# 22  15/01/2021         Digit Insurance      Financial Services
# 23  28/01/2021  Bombay Shaving Company  Consumer Goods Company
# 24  19/01/2021                  DeHaat        AgriTech Startup
# 25  19/01/2021               Darwinbox                    SaaS
# 26  18/01/2021                   mfine     Health Tech Startup
# 27  18/01/2021                   Udayy                  EdTech
# 28  11/01/2021           True Elements            Food Startup
# 29  13/01/2021                   Saveo          B2B E-commerce
#
#                                          Sub-vertical               City  \
# 6                            Online shopping platform  Jaipur, Rajasthan
# 7             Conversational Service Automation (CSA)          Palo Alto
# 8                            Hyper-local delivery app          Bengaluru
# 9                                     Online tutoring          Bengaluru
# 10                Career and job-oriented upskilling.          Bengaluru
# 11       Social ecommerce and online grocery platform            Gurgaon
# 12  Commerce and payments platform to offline ente...            Gurgaon
# 13                                E-Learning Platform            Gurgaon
# 14                      Online Food Delivery Platform            Gurgaon
# 15                      Semi-cooked food delivery app             Mumbai
# 16                             Global Neobank Venture             Mumbai
# 17                           Digital lending platform          Bengaluru
# 18                        Multi-brand furniture brand             Mumbai
# 19                                 Online supermarket            Gurgaon
# 20                        Consumer Technology Venture             London
# 21                      Game-based learning programme            Gurgaon
# 22                                 Insurance Services          Bengaluru
# 23      Shave care, beard care, and skincare products          New Delhi
# 24  online marketplace for farm products and services              Patna
# 25                                            HR Tech             Mumbai
# 26                 AI-powered telemedicine mobile app          Bengaluru
# 27     Online learning platform for kids in class 1-5            Gurgaon
# 28                      Whole Food plant based Nashta               Pune
# 29                                         Pharmacies          Bengaluru
#
#                                              Investor Investment Type  \
# 6                                     Innoven Capital  Debt Financing
# 7                           Sorenson Capital Partners        Series D
# 8                           Krishtal Advisors Pte Ltd        Series E
# 9          MC Global Edtech, B Capital, Baron, others        Series F
# 10                              Titan Capital, others            Seed
# 11                                     Accel Partners        Series A
# 12                                               PayU        Series A
# 13  SIG Global, Sequoia Capital, WaterBridge Ventu...        Series B
# 14                                 Tiger Global, Kora         Venture
# 15           Rhodium Trust, Accel Partners and Swiggy        Series C
# 16     Accel Partners and Lightspeed Venture Partners            Seed
# 17  Azim Premji’s PremjiInvest and South Korea’s M...        Series C
# 18                                    InnoVen Capital  Debt Financing
# 19                         SoftBank Vision Fund (SVF)     Unspecified
# 20                                                 GV        Series A
# 21                                       Owl Ventures        Series C
# 22   A91 Partners, Faering Capital, TVS Capital Funds         Venture
# 23                                  Reckitt Benckiser         Venture
# 24                                    Prosus Ventures        Series C
# 25                                Salesforce Ventures            Seed
# 26                         Heritas Capital Management   Venture Round
# 27                                    Sequoia Capital    Seed Funding
# 28                              SIDBI Venture Capital          Series
# 29          Matrix Partners India, RTP Global, others            Seed
#
#           Amount
# 6    250,000,000
# 7    140,000,000
# 8      8,000,000
# 9    460,000,000
# 10   300,000,000
# 11    11,000,000
# 12    27,500,000
# 13     2,500,000
# 14   250,000,000
# 15  2,747,045.20
# 16   1,50,00,000
# 17    75,000,000
# 18     4,773,958
# 19    55,000,000
# 20    15,000,000
# 21    18,000,000
# 22   1,80,00,000
# 23  6,172,258.50
# 24    30,000,000
# 25    15,000,000
# 26    16,000,000
# 27    15,000,000
# 28   100,000,000
# 29     4,000,000

# %% [markdown]
# 7. Write a program to scrap all the available details of best gaming laptops from digit.in

# %%
#importing all the required libraries
import pandas as pd
import selenium
import time
from selenium import webdriver
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
import warnings
warnings.filterwarnings("ignore")
from selenium.webdriver.common.keys import Keys

# %%
driver= webdriver.Chrome("chromedriver.exe")
url= 'https://www.digit.in/'
driver.get(url)
time.sleep(2)

# %%
top_10=driver.find_element_by_xpath("/html/body/div[1]/div/div[4]/ul/li[4]")
top_10.click()

# %%
laptop=driver.find_element_by_xpath("/html/body/div[3]/div/div/div[3]/div[2]/ul/li[26]")
laptop.click()

# %%
product_name=[]
p_n=driver.find_elements_by_xpath("//div[@class='right-container']/div/a/h3")
for i in p_n:
    product_name.append(i.text)
product_name
# Out:
# []

# %%
details=[]
o_s=driver.find_elements_by_xpath('//div[@class="product-detail"]')
for i in o_s:
    details.append(i.text.replace('\n','-'))
details
# Out:
# []

# %%
digit_lap=pd.DataFrame()
digit_lap['product_name']=product_name
digit_lap['details']=details
digit_lap
# Out:
# Empty DataFrame
# Columns: [product_name, details]
# Index: []
